# %% [markdown]
# <a href="https://colab.research.google.com/github/datadude1702/ml-bootcamp-2026/blob/main/version_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import sys

# %%
print(sys.version)
# Out:
# 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
