# %% [markdown]
# <a href="https://colab.research.google.com/github/datadude1702/ml-bootcamp-2026/blob/main/CS50_Lesson0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ( "hello world" )
# Out:
# hello world

# %%
input (" What's your name? ")
print ( "Nice to meet you" , input (" What's your name? "))
# Out:
#  What's your name? Arjun
#  What's your name? Arjun
# Nice to meet you Arjun

# %%
name = input ( " What's your name : " )
print ("hello" , name )
# Out:
#  What's your name : Arjun
# hello Arjun

# %%
#parameters
print ("Hello", "world", sep= ' ', end= '\n')
# Out:
# Hello world

# %%
 print (' hello, "friend" ')
# Out:
#  hello, "friend"

# %%
#escape character
print (" hello, \"friend\"")
# Out:
#  hello, "friend"

# %%
name = input ( " What's your name? ")
print ( f" hello, {name}")
# Out:
#  What's your name? Arjun
#  hello, Arjun

# %%
name = input ( " What's your name? ")
#remove whitespaces from str
name = name.strip()
print ( f" hello, {name}")
# Out:
#  What's your name?                       Arjun
#  hello, Arjun

# %%
name = input ( " What's your name? ")
name = name.strip()
#capititalize 1st letter
name = name.capitalize()
print ( f" hello, {name}")

# %%
name = input ( " What's your name? ")
name = name.strip()
name = name.title()
print ( f" hello, {name}")
# Out:
#  What's your name? arjun mukherjee
#  hello, Arjun Mukherjee

# %%
#chain the functions
name = input ( " What's your name? ")
name = name.strip().title()
print ( f" hello, {name}")
# Out:
#  What's your name? Arjun Mukherjee
#  hello, Arjun Mukherjee

# %%
name = input ( " What's your name? ").strip().title()
print ( f" hello, {name}")
# Out:
#  What's your name? arjun mukherjee
#  hello, Arjun Mukherjee

# %%
#split
name = input ( " What's your name? ").strip().title()
first, last = name.split(" ")
print ( f" hello, {first}")
# Out:
#  What's your name? arjun mukherjee
#  hello, Arjun

# %%
1 + 1
# Out:
# 2

# %%
x = 1
y = 2
z= x + y
print (z)
# Out:
# 3

# %%
#concatenation
x = input ( " What's x? ")
y = input ( " What's y? ")
z = x + y
print (z)
# Out:
#  What's x? 2
#  What's y? 4
# 24

# %%
x = input ( " What's x? ")
y = input ( " What's y? ")
z = int(x) + int(y)
print (z)
# Out:
#  What's x? 4
#  What's y? 2
# 6

# %%
x = int (input ( " What's x? "))
y = int (input ( " What's y? "))
print ( x + y )
# Out:
#  What's x? 4
#  What's y? 2
# 6

# %%
x = input ( " What's x? ")
y = input ( " What's y? ")
z = float (x) + float (y)
print (z)
# Out:
#  What's x? 4.25
#  What's y? 6.89
# 11.14

# %%
x = float (input ( " What's x? "))
y = float (input ( " What's y? "))
z = round(x+y)
print (z)
# Out:
#  What's x? 4.25
#  What's y? 3.2658
# 8

# %%
x = float (input ( " What's x? "))
y = float (input ( " What's y? "))
z = round(x+y)
print (f"{z:}")
# Out:
#  What's x? 42.568
#  What's y? 987.56
# 1030

# %%
x = float (input ( " What's x? "))
y = float (input ( " What's y? "))
z = round(x / y, 2)
print (z)
# Out:
#  What's x? 25
#  What's y? 7.1
# 3.52

# %%
x = float (input ( " What's x? "))
y = float (input ( " What's y? "))
z = round(x / y)
print (f"{z:.2f}")
# Out:
#  What's x? 25.89
#  What's y? 1.695
# 15.00

# %%
#define functions
def hello():
    print ("hello")
hello()
# Out:
# hello

# %%
#define functions-parameters
def hello(to):
    print ("hello" , to)
name = input (" What's your name? ")
hello(name)
# Out:
#  What's your name? arjun
# hello arjun

# %%
def hello(to="world"):
    print ("hello" , to)
hello()
name = input (" What's your name? ")
hello(name)
# Out:
# hello world
#  What's your name? arjun
# hello arjun

# %%
def hello(to="world"):
    print ("hello" , to)




































hello()
name = input (" What's your name? ")
hello(name)
# Out:
# hello world
#  What's your name? arjun
# hello arjun

# %%
def main():
  name = input (" What's your name: ")
  hello (name)


def hello (to = "world"):
  print (" hello, ", to)      #scope

main()
hello()
hello(name)
# Out:
#  What's your name: arjun
#  hello,  arjun
#  hello,  world
#  hello,  arjun

# %%
def main():
  x = int (input (" What's x="))

def square(n):
  return n*n
  return pow (n,2)

main()
square()
# Out:
#  What's x=8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1975/1676589170.py in <cell line: 0>()
#       7
#       8 main()
# ----> 9 square()
#
# TypeError: square() missing 1 required positional argument: 'n'
