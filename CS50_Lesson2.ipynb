# %% [markdown]
# <a href="https://colab.research.google.com/github/datadude1702/ml-bootcamp-2026/blob/main/CS50_Lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("meow")
print ("meow")
print ("meow")
# Out:
# meow
# meow
# meow

# %%
i = 3
while i != 0:
  print("meow")   #Ctrl C to stop infinite loop
  i=i-1
# Out:
# meow
# meow
# meow

# %%
i = 1
while i<= 3:
  print ("meow")
  i=i+1
# Out:
# meow
# meow
# meow

# %%
i = 1
while i<= 3:
  print ("meow")
  i += 1
# Out:
# meow
# meow
# meow

# %%
for i in [ 0, 1, 2]:
  print ("meow")
# Out:
# meow
# meow
# meow

# %%
for i in range(3):
  print ("meow")
# Out:
# meow
# meow
# meow

# %%
for _ in range(3):    # _ variable used single time
  print ("meow")
# Out:
# meow
# meow
# meow

# %%
print ("meow" *3)
# Out:
# meowmeowmeow

# %%
print ("meow\n" *3)
# Out:
# meow
# meow
# meow

# %%
print ("meow\n" *3, end = "")
# Out:
# meow
# meow
# meow

# %%
n = int(input("what's n?"))
for _ in range(n):
  print ("meow")
# Out:
# what's n?5
# meow
# meow
# meow
# meow
# meow

# %%
while True:
  n = int(input("what's n?"))
  if n > 0:
        break                                 #break


for _ in range(n):
  print ("meow")
# Out:
# what's n?5
# meow
# meow
# meow
# meow
# meow

# %%
def main():
  number = get_number()
  meow(number)

def get_number():
  while True:
    n = int(input("What's n?"))
    if n > 0:
      break
  return n


def meow():
  for _ in range(n):
    print ("meow")

meow()
# Out:
# meow
# meow
# meow
# meow
# meow

# %%
#hogwarts
students = ["Hermione", "Harry", "Ron"]
print (students[0])
print (students[1])
print (students[2])
# Out:
# Hermione
# Harry
# Ron

# %%
students = ["Hermione", "Harry", "Ron"]
print (students[0], students[1], students[2], sep='\n')
# Out:
# Hermione
# Harry
# Ron

# %%
students = ["Hermoine", "Harry", "Ron"]
for student in students:
  print (student)
# Out:
# Hermoine
# Harry
# Ron

# %%
students = ["Hermoine", "Harry", "Ron"]
for i in range(len(students)):       #LEN
  print (i + 1, students[i])
# Out:
# 1 Hermoine
# 2 Harry
# 3 Ron

# %%
#dict
students = {
    "Hermoine": "Gryffindor",
    "Harry": "Gryffindor",
    "Ron": "Gryffindor",
    "Draco": "Slytherin",
}
print (students["Hermoine"])
print (students["Harry"])
print (students["Ron"])
print (students["Draco"])
# Out:
# Gryffindor
# Gryffindor
# Gryffindor
# Slytherin

# %%
students = { "Hermoine": "Gryffindor", "Harry": "Gryffindor", "Ron": "Gryffindor", "Draco": "Slytherin",}
for student in students:
  print (student, students[student], sep=" , ")
# Out:
# Hermoine , Gryffindor
# Harry , Gryffindor
# Ron , Gryffindor
# Draco , Slytherin

# %%
students = [
    {"name": "Hermoine", "house": "Gryffindor", "patronus": "Otter"},
    {"name": "Harry", "house": "Gryffindor", "patronus": "Stag"},
    {"name": "Ron", "house": "Gryffindor", "patronus": "Jack Russell terrier"},
    {"name": "Draco", "house": "Slytherin", "patronus": None},
]
for student in students:
  print (student["name"], student["house"], student["patronus"], sep=", ")
# Out:
# Hermoine, Gryffindor, Otter
# Harry, Gryffindor, Stag
# Ron, Gryffindor, Jack Russell terrier
# Draco, Slytherin, None

# %%
students = [
    {"name": "Hermoine", "house": "Gryffindor", "patronus": "Otter"},
    {"name": "Harry", "house": "Gryffindor", "patronus": "Stag"},
    {"name": "Ron", "house": "Gryffindor", "patronus": "Jack Russell terrier"},
    {"name": "Draco", "house": "Slytherin", "patronus": None},
]
for student in students:
  print (student["name"], student["house"], student["patronus"], sep=", ")

# %%
#super mario bros
print (" # ")
print (" # ")
print (" # ")
# Out:
#  #
#  #
#  #

# %%
for _ in range(3):
  print (" # ")
# Out:
#  #
#  #
#  #

# %%
def main():
  print_column(3)

def print_column(height):
  for _ in range(height):
    print (" # ")

main()
# Out:
#  #
#  #
#  #

# %%
def main():
  print_column(3)

def print_column(height):
    print (" #\n" * height, end=" ")

main()
# Out:
#  #
#  #
#  #

# %%
def main():
  print(print_row(4))

def print_row(width):
  return "+" + ("-" * width) + "+"

main()
# Out:
# +----+

# %%
def main():
  print_square(3)

def print_square(size):
  for i in range(size):
    for j in range(size):
      print ("+", end="")
    print ()

main()
# Out:
# +++
# +++
# +++

# %%
def main():
  print_square(3)

def print_square(size):
  for i in range(size):
    print_row(size)

def print_row(width):
  print ("+" + ("-" * width) + "+")

main()


main()
